# %%
import pandas as pd
from google.colab import drive

# %%
drive.mount('my_drive')
# Out:
# Mounted at my_drive

# %%
f100 = pd.read_csv('/content/my_drive/MyDrive/CNRS Research/Deep_DeQuIP_100_FOCUS/log.csv', usecols=['epoch', 'mean_squared_error'])
f200 = pd.read_csv('/content/my_drive/MyDrive/CNRS Research/Deep_DeQuIP_200_FOCUS/log.csv', usecols=['epoch', 'mean_squared_error'])
f300 = pd.read_csv('/content/my_drive/MyDrive/CNRS Research/Deep_DeQuIP_300_FOCUS/log.csv', usecols=['epoch', 'mean_squared_error'])
f400 = pd.read_csv('/content/my_drive/MyDrive/CNRS Research/Deep_DeQuIP_400_FOCUS/log.csv', usecols=['epoch', 'mean_squared_error'])
l100 = pd.read_csv('/content/my_drive/MyDrive/CNRS Research/Deep_DeQuIP_100_LINEAR/log.csv', usecols=['epoch', 'mean_squared_error'])
l200 = pd.read_csv('/content/my_drive/MyDrive/CNRS Research/Deep_DeQuIP_200_LINEAR/log.csv', usecols=['epoch', 'mean_squared_error'])
l300 = pd.read_csv('/content/my_drive/MyDrive/CNRS Research/Deep_DeQuIP_300_LINEAR/log.csv', usecols=['epoch', 'mean_squared_error'])
l400 = pd.read_csv('/content/my_drive/MyDrive/CNRS Research/Deep_DeQuIP_400_LINEAR/log.csv', usecols=['epoch', 'mean_squared_error'])

# %%
print(l100)
print(l200)
# Out:
#     epoch  mean_squared_error
# 0       0            0.046525
# 1       1            0.041272
# 2       2            0.006388
# 3       3            0.004828
# 4       4            0.004157
# 5       5            0.088247
# 6       6            0.018524
# 7       7            0.017347
# 8       8            0.009986
# 9       9            0.005717
# 10     10            5.070503
# 11     11            0.023738
# 12     12            0.021101
# 13     13            0.019620
# 14     14            0.018819
#     epoch  mean_squared_error
# 0       0            0.207470
# 1       1            0.007175
# 2       2            0.005520
# 3       3            0.004681
# 4       4            0.004106
# 5       5            0.003677
# 6       6            0.397573
# 7       7            0.020662
# 8       8            0.019845
# 9       9            0.018970
# 10     10            0.017022
# 11     11            0.008665
# 12     12            0.005461
# 13     13            0.143436
# ...

# %%
l300
# Out:
#        mean_squared_error
# epoch
# 0                0.233663
# 1                0.016121
# 2                0.010119
# 3                0.053318
# 4                0.016086
# 5                0.007515
# 6                0.005555
# 7                0.004698
# 8                0.004149
# 9                0.024408
# 10               0.017362
# 11               0.008716
# 12               0.005326
# 13               0.041690
# 13               0.004549

# %%
import matplotlib.pyplot as plt

# %%
linear = {
    'Deep_DeQuIP_100_LINEAR': l100,
    'Deep_DeQuIP_200_LINEAR': l200,
    'Deep_DeQuIP_300_LINEAR': l300,
    'Deep_DeQuIP_400_LINEAR': l400,
}

# Create a plot
plt.figure(figsize=(10, 6))

# Plot each dataset
for label, df in linear.items():
    plt.plot(df['epoch'], df['mean_squared_error'], label=label)

plt.yscale('log')
plt.title("Comparison of Mean Squared Error over Epochs (LINEAR IMAGES)")
plt.xlabel("Epoch")
plt.ylabel("Mean Squared Error")
plt.legend()
plt.show()

# %%
focus = {
    'Deep_DeQuIP_100_FOCUS': f100,
    'Deep_DeQuIP_200_FOCUS': f200,
    'Deep_DeQuIP_300_FOCUS': f300,
    'Deep_DeQuIP_400_FOCUS': f400
}

# Create a plot
plt.figure(figsize=(10, 6))

# Plot each dataset
for label, df in focus.items():
    plt.plot(df['epoch'], df['mean_squared_error'], label=label)

plt.yscale('log')
plt.title("Comparison of Mean Squared Error over Epochs (FOCUS IMAGES)")
plt.xlabel("Epoch")
plt.ylabel("Mean Squared Error")
plt.legend()
plt.show()

# %%
datasets = {
    'Deep_DeQuIP_100_FOCUS': f100,
    'Deep_DeQuIP_200_FOCUS': f200,
    'Deep_DeQuIP_300_FOCUS': f300,
    'Deep_DeQuIP_400_FOCUS': f400,
    'Deep_DeQuIP_100_LINEAR': l100,
    'Deep_DeQuIP_200_LINEAR': l200,
    'Deep_DeQuIP_300_LINEAR': l300,
    'Deep_DeQuIP_400_LINEAR': l400,
}

# Create a plot
plt.figure(figsize=(10, 6))

# Plot each dataset
for label, df in datasets.items():
    plt.plot(df['epoch'], df['mean_squared_error'], label=label)

plt.yscale('log')
plt.title("Comparison of Mean Squared Error over Epochs (COMBINED PLOT)")
plt.xlabel("Epoch")
plt.ylabel("Mean Squared Error")
plt.legend()
plt.show()

# %%
# Plotting F_100 and L_100 for 25 epochs to show the overshooting of loss. Moreover, losses for LINEAR Images seem to be more noisy, compared to FOCUS Images.
plt.plot(f100['epoch'], f100['mean_squared_error'], label ='100_FOCUS')
plt.plot(l100['epoch'],l100['mean_squared_error'], label = '100_LINEAR')
plt.title('Comparison of Loss Convergence of Linear vs Focus')
plt.yscale('log')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.legend()
plt.show()

# %%
initial_model_100_epochs = pd.read_csv('/content/my_drive/MyDrive/CNRS Research/Deep_DeQuIP_US_image_despeckling_Train700_20_5x5_64/log.csv')

# %%
# Plotting initial DIVA model trained on 400 Linear Images for 100 epochs
plt.plot(initial_model_100_epochs['epoch'], initial_model_100_epochs['mean_squared_error'])
plt.title('DIVA Model trained on 400 LINEAR Images for 100 epochs ')
plt.yscale('log')
plt.xlabel('Epochs')
plt.ylabel('MSE')
plt.show()
